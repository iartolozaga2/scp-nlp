# %%
# !pip3 install --upgrade scpscraper
import scpscraper as scraper
# !pip3 install --upgrade html2text
import html2text as h2t
import json
import re
from tqdm import tqdm
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Requirement already satisfied: scpscraper in c:\programdata\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: beautifulsoup4>=4.9.1 in c:\programdata\anaconda3\lib\site-packages (from scpscraper) (4.9.3)
# Requirement already satisfied: soupsieve>=2.0.1 in c:\programdata\anaconda3\lib\site-packages (from scpscraper) (2.2.1)
# Requirement already satisfied: tqdm>=4.48.0 in c:\programdata\anaconda3\lib\site-packages (from scpscraper) (4.59.0)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (from scpscraper) (4.6.3)
# Requirement already satisfied: bs4>=0.0.1 in c:\programdata\anaconda3\lib\site-packages (from scpscraper) (0.0.1)
# Requirement already satisfied: html2text in c:\programdata\anaconda3\lib\site-packages (2020.1.16)

# %%
# Method to obtain the object/containment class of the SCP entities directly from their wiki entries' source code
def get_obj_classes(scp_list):
    obj_classes = {}
    for scp in scp_list:
        print("Getting object class of SCP#" + str(scp))
        try:
            scrape = scraper.get_scp(scp)
            scp_tags = [tag for tag in scrape['tags']]
            if 'safe' in scp_tags:
                obj_classes[scp] = 'Safe'
            else:
                if 'euclid' in scp_tags:
                    obj_classes[scp] = 'Euclid'
                else:
                    if 'keter' in scp_tags:
                        obj_classes[scp] = 'Keter'
                    else:
                        obj_classes[scp] = 'Outside of scope'
        except:
            obj_classes[scp] = 'Unavailable'
    return obj_classes
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# Method to obtain the descriptions of the SCP entities directly from their wiki entries' source code
def get_descriptions(scp_list):
    descriptions = {}
    for scp in scp_list:
        print("Getting description of SCP#" + str(scp))
        try:
            scrape = scraper.get_single_scp(scp)
            body = ' '.join([h2t.html2text(str(p)) for p in scrape.find_all('p')]).split("**")
            descloc = [index for index in range(len(body)) if body[index] == 'Description:' or body[index] == 'Description'][0]
            descriptions[scp] = ' '.join((body[(descloc+1)]).split('\n'))
        except:
            descriptions[scp] = 'Unavailable'
        
    return descriptions
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# Method to obtain the special containment procedures of the SCP entities directly from their wiki entries' source code
def get_spconprocs(scp_list):
    spconprocs = {}
    for scp in scp_list:
        print("Getting special containment procedures of SCP#" + str(scp))
        try:
            scrape = scraper.get_single_scp(scp)
            body = ' '.join([h2t.html2text(str(p)) for p in scrape.find_all('p')]).split("**")
            descloc = [index for index in range(len(body)) if body[index] == 'Special Containment Procedures:' or body[index] == 'Special Containment Procedures'][0]
            spconprocs[scp] = ' '.join((body[(descloc+1)]).split('\n'))
        except:
            spconprocs[scp] = 'Unavailable'
            
    return spconprocs
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# Method to build the json object with the id, the object class, the description and the ...
# ... containment procedures of each SCP entity, and export it to a file.
def build_json(scp_list):
    json_dict = {}
    obj_classes = get_obj_classes(scp_list)
    descs = get_descriptions(scp_list)
    spconprocs = get_spconprocs(scp_list)
    print("Building json...")
    for scp in scp_list:
        json_dict[scp] = {
            "obj_class": re.sub("[^a-zA-Z\d\s:]", "", str(obj_classes[scp])),
            "desc": re.sub("[^a-zA-Z\d\s:]", "", str(descs[scp])),
            "spconproc": re.sub("[^a-zA-Z\d\s:]", "", str(spconprocs[scp]))
        }
    json_string = json.dumps(json_dict)
    with open("scps.json", "w") as json_output:
        json_output.write(json_string)
    print("Done!")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# Formatting the SCP IDs to use them for SCPScraper
def add_zeroes(number_string):
    if len(number_string) == 1:
        return '00' + number_string
    if len(number_string) == 2:
        return '0' + number_string
    return number_string

# Here the SCPs to be included in the scraping can be indicated
int_array = range(1,7000)
string_array = [str(i) for i in int_array]
formatted_array = [add_zeroes(i) for i in string_array]
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
build_json(formatted_array)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Getting object class of SCP#001
# Getting object class of SCP#002
# Getting object class of SCP#003
# Getting object class of SCP#004
# Getting object class of SCP#005
# Getting object class of SCP#006
# Getting object class of SCP#007
# Getting object class of SCP#008
# Getting object class of SCP#009
# Getting object class of SCP#010
# Getting object class of SCP#011
# Getting object class of SCP#012
# Getting object class of SCP#013
# Getting object class of SCP#014
# Getting object class of SCP#015
# Getting object class of SCP#016
# Getting object class of SCP#017
# Getting object class of SCP#018
# Getting object class of SCP#019
# Getting object class of SCP#020
# Getting object class of SCP#021
# Getting object class of SCP#022
# Getting object class of SCP#023
# Getting object class of SCP#024
# Getting object class of SCP#025
# Getting object class of SCP#026
# Getting object class of SCP#027
# Getting object class of SCP#028
# Getting object class of SCP#029
# Getting object class of SCP#030
# Getting object class of SCP#031
# Getting object class of SCP#032
# Getting object class of SCP#033
# Getting object class of SCP#034
# Getting object class of SCP#035
# Getting object class of SCP#036
# Getting object class of SCP#037
# Getting object class of SCP#038
# Getting object class of SCP#039
# Getting object class of SCP#040
# Getting object class of SCP#041
# Getting object class of SCP#042
# Getting object class of SCP#043
# Getting object class of SCP#044
# Getting object class of SCP#045
# Getting object class of SCP#046
# Getting object class of SCP#047
# Getting object class of SCP#048
# Getting object class of SCP#049
# Getting object class of SCP#050
# Getting object class of SCP#051
# Getting object class of SCP#052
# Getting object class of SCP#053
# Getting object class of SCP#054
# Getting object class of SCP#055
# Getting object class of SCP#056
# Getting object class of SCP#057
# Getting object class of SCP#058
# Getting object class of SCP#059
# Getting object class of SCP#060
# Getting object class of SCP#061
# Getting object class of SCP#062
# Getting object class of SCP#063
# Getting object class of SCP#064
# Getting object class of SCP#065
# Getting object class of SCP#066
# Getting object class of SCP#067
# Getting object class of SCP#068
# Getting object class of SCP#069
# Getting object class of SCP#070
# Getting object class of SCP#071
# Getting object class of SCP#072
# Getting object class of SCP#073
# Getting object class of SCP#074
# Getting object class of SCP#075
# Getting object class of SCP#076
# Getting object class of SCP#077
# Getting object class of SCP#078
# Getting object class of SCP#079
# Getting object class of SCP#080
# Getting object class of SCP#081
# Getting object class of SCP#082
# Getting object class of SCP#083
# Getting object class of SCP#084
# Getting object class of SCP#085
# Getting object class of SCP#086
# Getting object class of SCP#087
# Getting object class of SCP#088
# Getting object class of SCP#089
# Getting object class of SCP#090
# Getting object class of SCP#091
# Getting object class of SCP#092
# Getting object class of SCP#093
# Getting object class of SCP#094
# Getting object class of SCP#095
# Getting object class of SCP#096
# Getting object class of SCP#097
# Getting object class of SCP#098
# Getting object class of SCP#099
# Getting object class of SCP#100
# Getting object class of SCP#101
# Getting object class of SCP#102
# Getting object class of SCP#103
# Getting object class of SCP#104
# Getting object class of SCP#105
# Getting object class of SCP#106
# Getting object class of SCP#107
# Getting object class of SCP#108
# Getting object class of SCP#109
# Getting object class of SCP#110
# Getting object class of SCP#111
# Getting object class of SCP#112
# Getting object class of SCP#113
# Getting object class of SCP#114
# Getting object class of SCP#115
# Getting object class of SCP#116
# Getting object class of SCP#117
# Getting object class of SCP#118
# Getting object class of SCP#119
# Getting object class of SCP#120
# Getting object class of SCP#121
# Getting object class of SCP#122
# Getting object class of SCP#123
# Getting object class of SCP#124
# Getting object class of SCP#125
# Getting object class of SCP#126
# Getting object class of SCP#127
# Getting object class of SCP#128
# Getting object class of SCP#129
# Getting object class of SCP#130
# Getting object class of SCP#131
# Getting object class of SCP#132
# Getting object class of SCP#133
# Getting object class of SCP#134
# Getting object class of SCP#135
# Getting object class of SCP#136
# Getting object class of SCP#137
# Getting object class of SCP#138
# Getting object class of SCP#139
# Getting object class of SCP#140
# Getting object class of SCP#141
# Getting object class of SCP#142
# Getting object class of SCP#143
# Getting object class of SCP#144
# Getting object class of SCP#145
# Getting object class of SCP#146
# Getting object class of SCP#147
# Getting object class of SCP#148
# Getting object class of SCP#149
# Getting object class of SCP#150
# Getting object class of SCP#151
# Getting object class of SCP#152
# Getting object class of SCP#153
# Getting object class of SCP#154
# Getting object class of SCP#155
# Getting object class of SCP#156
# Getting object class of SCP#157
# Getting object class of SCP#158
# Getting object class of SCP#159
# Getting object class of SCP#160
# Getting object class of SCP#161
# Getting object class of SCP#162
# Getting object class of SCP#163
# Getting object class of SCP#164
# Getting object class of SCP#165
# Getting object class of SCP#166
# Getting object class of SCP#167
# Getting object class of SCP#168
# Getting object class of SCP#169
# Getting object class of SCP#170
# Getting object class of SCP#171
# Getting object class of SCP#172
# Getting object class of SCP#173
# Getting object class of SCP#174
# Getting object class of SCP#175
# Getting object class of SCP#176
# Getting object class of SCP#177
# Getting object class of SCP#178
# Getting object class of SCP#179
# Getting object class of SCP#180
# Getting object class of SCP#181
# Getting object class of SCP#182
# Getting object class of SCP#183
# Getting object class of SCP#184
# Getting object class of SCP#185
# Getting object class of SCP#186
# Getting object class of SCP#187
# Getting object class of SCP#188
# Getting object class of SCP#189
# Getting object class of SCP#190
# Getting object class of SCP#191
# Getting object class of SCP#192
# Getting object class of SCP#193
# Getting object class of SCP#194
# Getting object class of SCP#195
# Getting object class of SCP#196
# Getting object class of SCP#197
# Getting object class of SCP#198
# Getting object class of SCP#199
# Getting object class of SCP#200
# Getting object class of SCP#201
# Getting object class of SCP#202
# Getting object class of SCP#203
# Getting object class of SCP#204
# Getting object class of SCP#205
# Getting object class of SCP#206
# Getting object class of SCP#207
# Getting object class of SCP#208
# Getting object class of SCP#209
# Getting object class of SCP#210
# Getting object class of SCP#211
# Getting object class of SCP#212
# Getting object class of SCP#213
# Getting object class of SCP#214
# Getting object class of SCP#215
# Getting object class of SCP#216
# Getting object class of SCP#217
# Getting object class of SCP#218
# Getting object class of SCP#219
# Getting object class of SCP#220
# Getting object class of SCP#221
# Getting object class of SCP#222
# Getting object class of SCP#223
# Getting object class of SCP#224
# Getting object class of SCP#225
# Getting object class of SCP#226
# Getting object class of SCP#227
# Getting object class of SCP#228
# Getting object class of SCP#229
# Getting object class of SCP#230
# Getting object class of SCP#231
# Getting object class of SCP#232
# Getting object class of SCP#233
# Getting object class of SCP#234
# Getting object class of SCP#235
# Getting object class of SCP#236
# Getting object class of SCP#237
# Getting object class of SCP#238
# Getting object class of SCP#239
# Getting object class of SCP#240
# Getting object class of SCP#241
# Getting object class of SCP#242
# Getting object class of SCP#243
# Getting object class of SCP#244
# Getting object class of SCP#245
# Getting object class of SCP#246
# Getting object class of SCP#247
# Getting object class of SCP#248
# Getting object class of SCP#249
# Getting object class of SCP#250
# Getting object class of SCP#251
# Getting object class of SCP#252
# Getting object class of SCP#253
# Getting object class of SCP#254
# Getting object class of SCP#255
# Getting object class of SCP#256
# Getting object class of SCP#257
# Getting object class of SCP#258
# Getting object class of SCP#259
# Getting object class of SCP#260
# Getting object class of SCP#261
# Getting object class of SCP#262
# Getting object class of SCP#263
# Getting object class of SCP#264
# Getting object class of SCP#265
# Getting object class of SCP#266
# Getting object class of SCP#267
# Getting object class of SCP#268
# Getting object class of SCP#269
# Getting object class of SCP#270
# Getting object class of SCP#271
# Getting object class of SCP#272
# Getting object class of SCP#273
# Getting object class of SCP#274
# Getting object class of SCP#275
# Getting object class of SCP#276
# Getting object class of SCP#277
# Getting object class of SCP#278
# Getting object class of SCP#279
# Getting object class of SCP#280
# Getting object class of SCP#281
# Getting object class of SCP#282
# Getting object class of SCP#283
# Getting object class of SCP#284
# Getting object class of SCP#285
# Getting object class of SCP#286
# Getting object class of SCP#287
# Getting object class of SCP#288
# Getting object class of SCP#289
# Getting object class of SCP#290
# Getting object class of SCP#291
# Getting object class of SCP#292
# Getting object class of SCP#293
# Getting object class of SCP#294
# Getting object class of SCP#295
# Getting object class of SCP#296
# Getting object class of SCP#297
# Getting object class of SCP#298
# Getting object class of SCP#299
# Getting object class of SCP#300
# Getting object class of SCP#301
# Getting object class of SCP#302
# Getting object class of SCP#303
# Getting object class of SCP#304
# Getting object class of SCP#305
# Getting object class of SCP#306
# Getting object class of SCP#307
# Getting object class of SCP#308
# Getting object class of SCP#309
# Getting object class of SCP#310
# Getting object class of SCP#311
# Getting object class of SCP#312
# Getting object class of SCP#313
# Getting object class of SCP#314
# Getting object class of SCP#315
# Getting object class of SCP#316
# Getting object class of SCP#317
# Getting object class of SCP#318
# Getting object class of SCP#319
# Getting object class of SCP#320
# Getting object class of SCP#321
# Getting object class of SCP#322
# Getting object class of SCP#323
# Getting object class of SCP#324
# Getting object class of SCP#325
# Getting object class of SCP#326
# Getting object class of SCP#327
# Getting object class of SCP#328
# Getting object class of SCP#329
# Getting object class of SCP#330
# Getting object class of SCP#331
# Getting object class of SCP#332
# Getting object class of SCP#333
# Getting object class of SCP#334
# Getting object class of SCP#335
# Getting object class of SCP#336
# Getting object class of SCP#337
# Getting object class of SCP#338
# Getting object class of SCP#339
# Getting object class of SCP#340
# Getting object class of SCP#341
# Getting object class of SCP#342
# Getting object class of SCP#343
# Getting object class of SCP#344
# Getting object class of SCP#345
# Getting object class of SCP#346
# Getting object class of SCP#347
# Getting object class of SCP#348
# Getting object class of SCP#349
# Getting object class of SCP#350
# Getting object class of SCP#351
# Getting object class of SCP#352
# Getting object class of SCP#353
# Getting object class of SCP#354
# Getting object class of SCP#355
# Getting object class of SCP#356
# Getting object class of SCP#357
# Getting object class of SCP#358
# Getting object class of SCP#359
# Getting object class of SCP#360
# Getting object class of SCP#361
# Getting object class of SCP#362
# Getting object class of SCP#363
# Getting object class of SCP#364
# Getting object class of SCP#365
# Getting object class of SCP#366
# Getting object class of SCP#367
# Getting object class of SCP#368
# Getting object class of SCP#369
# Getting object class of SCP#370
# Getting object class of SCP#371
# Getting object class of SCP#372
# Getting object class of SCP#373
# Getting object class of SCP#374
# Getting object class of SCP#375
# Getting object class of SCP#376
# Getting object class of SCP#377
# Getting object class of SCP#378
# Getting object class of SCP#379
# Getting object class of SCP#380
# Getting object class of SCP#381
# Getting object class of SCP#382
# Getting object class of SCP#383
# Getting object class of SCP#384
# Getting object class of SCP#385
# Getting object class of SCP#386
# Getting object class of SCP#387
# Getting object class of SCP#388
# Getting object class of SCP#389
# Getting object class of SCP#390
# Getting object class of SCP#391
# Getting object class of SCP#392
# Getting object class of SCP#393
# Getting object class of SCP#394
# Getting object class of SCP#395
# Getting object class of SCP#396
# Getting object class of SCP#397
# Getting object class of SCP#398
# Getting object class of SCP#399
# Getting object class of SCP#400
# Getting object class of SCP#401
# Getting object class of SCP#402
# Getting object class of SCP#403
# Getting object class of SCP#404
# Getting object class of SCP#405
# Getting object class of SCP#406
# Getting object class of SCP#407
# Getting object class of SCP#408
# Getting object class of SCP#409
# Getting object class of SCP#410
# Getting object class of SCP#411
# Getting object class of SCP#412
# Getting object class of SCP#413
# Getting object class of SCP#414
# Getting object class of SCP#415
# Getting object class of SCP#416
# Getting object class of SCP#417
# Getting object class of SCP#418
# Getting object class of SCP#419
# Getting object class of SCP#420
# Getting object class of SCP#421
# Getting object class of SCP#422
# Getting object class of SCP#423
# Getting object class of SCP#424
# Getting object class of SCP#425
# Getting object class of SCP#426
# Getting object class of SCP#427
# Getting object class of SCP#428
# Getting object class of SCP#429
# Getting object class of SCP#430
# Getting object class of SCP#431
# Getting object class of SCP#432
# Getting object class of SCP#433
# Getting object class of SCP#434
# Getting object class of SCP#435
# Getting object class of SCP#436
# Getting object class of SCP#437
# Getting object class of SCP#438
# Getting object class of SCP#439
# Getting object class of SCP#440
# Getting object class of SCP#441
# Getting object class of SCP#442
# Getting object class of SCP#443
# Getting object class of SCP#444
# Getting object class of SCP#445
# Getting object class of SCP#446
# Getting object class of SCP#447
# Getting object class of SCP#448
# Getting object class of SCP#449
# Getting object class of SCP#450
# Getting object class of SCP#451
# Getting object class of SCP#452
# Getting object class of SCP#453
# Getting object class of SCP#454
# Getting object class of SCP#455
# Getting object class of SCP#456
# Getting object class of SCP#457
# Getting object class of SCP#458
# Getting object class of SCP#459
# Getting object class of SCP#460
# Getting object class of SCP#461
# Getting object class of SCP#462
# Getting object class of SCP#463
# Getting object class of SCP#464
# Getting object class of SCP#465
# Getting object class of SCP#466
# Getting object class of SCP#467
# Getting object class of SCP#468
# Getting object class of SCP#469
# Getting object class of SCP#470
# Getting object class of SCP#471
# Getting object class of SCP#472
# Getting object class of SCP#473
# Getting object class of SCP#474
# Getting object class of SCP#475
# Getting object class of SCP#476
# Getting object class of SCP#477
# Getting object class of SCP#478
# Getting object class of SCP#479
# Getting object class of SCP#480
# Getting object class of SCP#481
# Getting object class of SCP#482
# Getting object class of SCP#483
# Getting object class of SCP#484
# Getting object class of SCP#485
# Getting object class of SCP#486
# Getting object class of SCP#487
# Getting object class of SCP#488
# Getting object class of SCP#489
# Getting object class of SCP#490
# Getting object class of SCP#491
# Getting object class of SCP#492
# Getting object class of SCP#493
# Getting object class of SCP#494
# Getting object class of SCP#495
# Getting object class of SCP#496
# Getting object class of SCP#497
# Getting object class of SCP#498
# Getting object class of SCP#499
# Getting object class of SCP#500
# Getting object class of SCP#501
# Getting object class of SCP#502
# Getting object class of SCP#503
# Getting object class of SCP#504
# Getting object class of SCP#505
# Getting object class of SCP#506
# Getting object class of SCP#507
# Getting object class of SCP#508
# Getting object class of SCP#509
# Getting object class of SCP#510
# Getting object class of SCP#511
# Getting object class of SCP#512
# Getting object class of SCP#513
# Getting object class of SCP#514
# Getting object class of SCP#515
# Getting object class of SCP#516
# Getting object class of SCP#517
# Getting object class of SCP#518
# Getting object class of SCP#519
# Getting object class of SCP#520
# Getting object class of SCP#521
# Getting object class of SCP#522
# Getting object class of SCP#523
# Getting object class of SCP#524
# Getting object class of SCP#525
# Getting object class of SCP#526
# Getting object class of SCP#527
# Getting object class of SCP#528
# Getting object class of SCP#529
# Getting object class of SCP#530
# Getting object class of SCP#531
# Getting object class of SCP#532
# Getting object class of SCP#533
# Getting object class of SCP#534
# Getting object class of SCP#535
# Getting object class of SCP#536
# Getting object class of SCP#537
# Getting object class of SCP#538
# Getting object class of SCP#539
# Getting object class of SCP#540
# Getting object class of SCP#541
# Getting object class of SCP#542
# Getting object class of SCP#543
# Getting object class of SCP#544
# Getting object class of SCP#545
# Getting object class of SCP#546
# Getting object class of SCP#547
# Getting object class of SCP#548
# Getting object class of SCP#549
# Getting object class of SCP#550
# Getting object class of SCP#551
# Getting object class of SCP#552
# Getting object class of SCP#553
# Getting object class of SCP#554
# Getting object class of SCP#555
# Getting object class of SCP#556
# Getting object class of SCP#557
# Getting object class of SCP#558
# Getting object class of SCP#559
# Getting object class of SCP#560
# Getting object class of SCP#561
# Getting object class of SCP#562
# Getting object class of SCP#563
# Getting object class of SCP#564
# Getting object class of SCP#565
# Getting object class of SCP#566
# Getting object class of SCP#567
# Getting object class of SCP#568
# Getting object class of SCP#569
# Getting object class of SCP#570
# Getting object class of SCP#571
# Getting object class of SCP#572
# Getting object class of SCP#573
# Getting object class of SCP#574
# Getting object class of SCP#575
# Getting object class of SCP#576
# Getting object class of SCP#577
# Getting object class of SCP#578
# Getting object class of SCP#579
# Getting object class of SCP#580
# Getting object class of SCP#581
# Getting object class of SCP#582
# Getting object class of SCP#583
# Getting object class of SCP#584
# Getting object class of SCP#585
# Getting object class of SCP#586
# Getting object class of SCP#587
# Getting object class of SCP#588
# Getting object class of SCP#589
# Getting object class of SCP#590
# Getting object class of SCP#591
# Getting object class of SCP#592
# Getting object class of SCP#593
# Getting object class of SCP#594
# Getting object class of SCP#595
# Getting object class of SCP#596
# Getting object class of SCP#597
# Getting object class of SCP#598
# Getting object class of SCP#599
# Getting object class of SCP#600
# Getting object class of SCP#601
# Getting object class of SCP#602
# Getting object class of SCP#603
# Getting object class of SCP#604
# Getting object class of SCP#605
# Getting object class of SCP#606
# Getting object class of SCP#607
# Getting object class of SCP#608
# Getting object class of SCP#609
# Getting object class of SCP#610
# Getting object class of SCP#611
# Getting object class of SCP#612
# Getting object class of SCP#613
# Getting object class of SCP#614
# Getting object class of SCP#615
# Getting object class of SCP#616
# Getting object class of SCP#617
# Getting object class of SCP#618
# Getting object class of SCP#619
# Getting object class of SCP#620
# Getting object class of SCP#621
# Getting object class of SCP#622
# Getting object class of SCP#623
# Getting object class of SCP#624
# Getting object class of SCP#625
# Getting object class of SCP#626
# Getting object class of SCP#627
# Getting object class of SCP#628
# Getting object class of SCP#629
# Getting object class of SCP#630
# Getting object class of SCP#631
# Getting object class of SCP#632
# Getting object class of SCP#633
# Getting object class of SCP#634
# Getting object class of SCP#635
# Getting object class of SCP#636
# Getting object class of SCP#637
# Getting object class of SCP#638
# Getting object class of SCP#639
# Getting object class of SCP#640
# Getting object class of SCP#641
# Getting object class of SCP#642
# Getting object class of SCP#643
# Getting object class of SCP#644
# Getting object class of SCP#645
# Getting object class of SCP#646
# Getting object class of SCP#647
# Getting object class of SCP#648
# Getting object class of SCP#649
# Getting object class of SCP#650
# Getting object class of SCP#651
# Getting object class of SCP#652
# Getting object class of SCP#653
# Getting object class of SCP#654
# Getting object class of SCP#655
# Getting object class of SCP#656
# Getting object class of SCP#657
# Getting object class of SCP#658
# Getting object class of SCP#659
# Getting object class of SCP#660
# Getting object class of SCP#661
# Getting object class of SCP#662
# Getting object class of SCP#663
# Getting object class of SCP#664
# Getting object class of SCP#665
# Getting object class of SCP#666
# Getting object class of SCP#667
# Getting object class of SCP#668
# Getting object class of SCP#669
# Getting object class of SCP#670
# Getting object class of SCP#671
# Getting object class of SCP#672
# Getting object class of SCP#673
# Getting object class of SCP#674
# Getting object class of SCP#675
# Getting object class of SCP#676
# Getting object class of SCP#677
# Getting object class of SCP#678
# Getting object class of SCP#679
# Getting object class of SCP#680
# Getting object class of SCP#681
# Getting object class of SCP#682
# Getting object class of SCP#683
# Getting object class of SCP#684
# Getting object class of SCP#685
# Getting object class of SCP#686
# Getting object class of SCP#687
# Getting object class of SCP#688
# Getting object class of SCP#689
# Getting object class of SCP#690
# Getting object class of SCP#691
# Getting object class of SCP#692
# Getting object class of SCP#693
# Getting object class of SCP#694
# Getting object class of SCP#695
# Getting object class of SCP#696
# Getting object class of SCP#697
# Getting object class of SCP#698
# Getting object class of SCP#699
# Getting object class of SCP#700
# Getting object class of SCP#701
# Getting object class of SCP#702
# Getting object class of SCP#703
# Getting object class of SCP#704
# Getting object class of SCP#705
# Getting object class of SCP#706
# Getting object class of SCP#707
# Getting object class of SCP#708
# Getting object class of SCP#709
# Getting object class of SCP#710
# Getting object class of SCP#711
# Getting object class of SCP#712
# Getting object class of SCP#713
# Getting object class of SCP#714
# Getting object class of SCP#715
# Getting object class of SCP#716
# Getting object class of SCP#717
# Getting object class of SCP#718
# Getting object class of SCP#719
# Getting object class of SCP#720
# Getting object class of SCP#721
# Getting object class of SCP#722
# Getting object class of SCP#723
# Getting object class of SCP#724
# Getting object class of SCP#725
# Getting object class of SCP#726
# Getting object class of SCP#727
# Getting object class of SCP#728
# Getting object class of SCP#729
# Getting object class of SCP#730
# Getting object class of SCP#731
# Getting object class of SCP#732
# Getting object class of SCP#733
# Getting object class of SCP#734
# Getting object class of SCP#735
# Getting object class of SCP#736
# Getting object class of SCP#737
# Getting object class of SCP#738
# Getting object class of SCP#739
# Getting object class of SCP#740
# Getting object class of SCP#741
# Getting object class of SCP#742
# Getting object class of SCP#743
# Getting object class of SCP#744
# Getting object class of SCP#745
# Getting object class of SCP#746
# Getting object class of SCP#747
# Getting object class of SCP#748
# Getting object class of SCP#749
# Getting object class of SCP#750
# Getting object class of SCP#751
# Getting object class of SCP#752
# Getting object class of SCP#753
# Getting object class of SCP#754
# Getting object class of SCP#755
# Getting object class of SCP#756
# Getting object class of SCP#757
# Getting object class of SCP#758
# Getting object class of SCP#759
# Getting object class of SCP#760
# Getting object class of SCP#761
# Getting object class of SCP#762
# Getting object class of SCP#763
# Getting object class of SCP#764
# Getting object class of SCP#765
# Getting object class of SCP#766
# Getting object class of SCP#767
# Getting object class of SCP#768
# Getting object class of SCP#769
# Getting object class of SCP#770
# Getting object class of SCP#771
# Getting object class of SCP#772
# Getting object class of SCP#773
# Getting object class of SCP#774
# Getting object class of SCP#775
# Getting object class of SCP#776
# Getting object class of SCP#777
# Getting object class of SCP#778
# Getting object class of SCP#779
# Getting object class of SCP#780
# Getting object class of SCP#781
# Getting object class of SCP#782
# Getting object class of SCP#783
# Getting object class of SCP#784
# Getting object class of SCP#785
# Getting object class of SCP#786

# %%
# Output formatting stuff, please ignore
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
